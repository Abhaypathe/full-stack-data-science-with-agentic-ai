# %% [markdown]
# # Python Indexing:
#
#         Python index begin with 0
#         python index has two parts :
# ### 1. Forward indexing (left to right )index
#         -->starts from 0
#
# ### 2.Backward Indexing ( Right to left ) index
#       -->starts from -1

# %%
si='welcome'
si
# Out:
# 'welcome'

# %%
si[0]
# Out:
# 'w'

# %%
si[5]
# Out:
# 'm'

# %%
si[6]
# Out:
# 'e'

# %%
si[-2]
# Out:
# 'm'

# %%
si[-6]
# Out:
# 'e'

# %% [markdown]
# # Python slicing

# %% [markdown]
# si[:]----->print all
#
# [L:R]--->right will be apply (n-1) not left index

# %%
si[:]
# Out:
# 'welcome'

# %%
si[1:4]    #(4-1)=3index it will print upto 3index
# Out:
# 'elc'

# %%
si[0:6]
# Out:
# 'welcom'

# %%
si[3:7]
# Out:
# 'come'

# %%
si[3:10]
# Out:
# 'come'

# %%
si[3:5]
# Out:
# 'co'

# %%
si[3:]
# Out:
# 'come'

# %%
si[1:]
# Out:
# 'elcome'

# %%
si[:4]
# Out:
# 'welc'

# %%
si[:6]
# Out:
# 'welcom'

# %% [markdown]
# ## Advance Slicing

# %% [markdown]
# ### Step slicing
# ------------------------
# -[left : Right : Step ]   --->left index start with 0
#                             --->right index (n-1)
#                             ---->step how to slice the number

# %%
si[0:7:2]
# Out:
# 'wloe'

# %%
si[0:6:4]
# Out:
# 'wo'

# %%
si[0:7:2]
# Out:
# 'wloe'
