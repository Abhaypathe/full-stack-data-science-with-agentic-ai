# %% [markdown]
# # VARIABLE
# -Variable are used for storing values and its location in memory.
#
# -In python, Variables are dynamic. (we don't declare the type of variable)
#
# -the declaration of datatype happens automatically when you assign value to a variable.

# %% [markdown]
# declaring a variable: -eg. x=1 | | variable value ...........>value can be numerical or non numerical

# %% [markdown]
# Name = identifiers RULES
# 1.A variable name must start with a letter (a-z) (A-Z) OR the (_)
# 2. a variable accepts only _.
# 3. name ca not start with a number
# 4. it contains alpha numeric characters and _
# 5.they are case sensitive .---> capital or small letter
# 6.reserve keyword not accept.

# %% [markdown]
# To store multiple values : list, tuple, set, dict

# %%
a=10
type(a)
# Out:
# int

# %%
b=10,20,30
type(b)
# Out:
# tuple

# %%
c=-28
type(c)
# Out:
# int

# %%
z=True
type(z)
# Out:
# bool

# %%
y=False
type(y)
# Out:
# bool

# %%
#private variable   ------------- underscore se start karne vale variable private hote hai 
# agar isko show karna hai to use karo print( _a )
_a=92
print(_a)
type(_a)
# Out:
# 92
# int

# %%
_a=87
print(_a)
# Out:
# 87

# %%
y="True"
type(y)
# Out:
# str

# %% [markdown]
# Latest values stored into variable -> a=10
#
#  aur badme agar likha
#  -> a= 20
# then it store 20 only

# %%
#assign multiple variable in a line
a,b,c = 10,20,30

# %%
#in single variable we can assign single or a multiple values
a=40,50,60

# %%
#delete 
a=50
del a     #agar backspace  se del kiya to code m modification honga but space nhi

# %%
#del multiple variable 
del a1,b1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #del multiple variable
# ----> 2 del a1,b1
#
# NameError: name 'a1' is not defined

# %%
 **OUTPUT**
        -print()
          |
        keyword

# %%
#print a single value
print (12)

# %%
#multiple values
print(12,14,15)    # by default space aajayegi

print(12,14,15, sep =" ,")  #sep is an seprator

# %%
#print multiple variable 
a=10
b=20
print(a,b)

# %%
#combination of both values and variables
print(12,a)
