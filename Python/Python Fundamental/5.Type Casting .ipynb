# %% [markdown]
# # TYPE CASTING
#
# -convert from one datatype to another datatype

# %% [markdown]
# ### int
#
# ------float,boolean ,string to int possible
# ------complex is not possible and text string is not possible

# %%
#int 
a=10

# %%
b=10.34
b
# Out:
# 10.34

# %%
int(10.34)  #float-->int
# Out:
# 10

# %%
int(b)
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
 int(1+2j)    #complex is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
 int("Ten")    #text string is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int("Ten")
#
# ValueError: invalid literal for int() with base 10: 'Ten'

# %% [markdown]
# ### float
#
# ---int bool string possible
#
# could not convert string to float
# float() argument must be a string or a real number, not 'complex

# %%
float(99)
# Out:
# 99.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# ## Bool
#
# every data type is possible

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
 bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %% [markdown]
# ## complex
#
# every datatypes is possible except the string with one argument is possible

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
complex(1.3,4.5)
# Out:
# (1.3+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('19')
# Out:
# (19+0j)

# %%
complex('Ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 complex('Ten')
#
# ValueError: complex() arg is a malformed string
