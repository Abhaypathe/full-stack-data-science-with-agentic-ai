# %% [markdown]
# # DATA TYPES
#
#             -Data types is assigned automatically based on values
#                         -DYNAMIC PROGRAMMING
#
#              -YOU CAN STORE SINGLE VALUE IN OBJECT
#                          -FUNDAMENTAL DATA TYPE
#                                 1.integer   (int)
#                                 2.float     (float)
#                                 3.boolean   (bool)
#                                 4.complex
#                                 5.string    (str)

# %% [markdown]
# ## 1. INTEGER :
#                         Numerical value with no decimal.
#                         can be either positive or negative or zero.

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
type(10)
# Out:
# int

# %%
type(a)
# Out:
# int

# %%
id(a)
# Out:
# 140727592465608

# %% [markdown]
# ## 2. FLOAT :
# numerical value with decimal number

# %%
b=10.2
print(b)

type(b)

id(b)
# Out:
# 10.2
# 2589830821264

# %%
type(b)
# Out:
# float

# %% [markdown]
# ## 3.Boolean :
#                 (bool)
#                    -True
#                    -False

# %%
b1=True
print(b1)
# Out:
# True

# %%
type(b1)
# Out:
# bool

# %%
True + False
# Out:
# 1

# %%
True* False
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %% [markdown]
# ## 4. Complex :
# format of complex = a+bj
#       a-real part
#       b-imaginary part
#       j-square root of -1

# %%
c =10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10 +20j
c1 =20+30j

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c +c1
# Out:
# (30+50j)

# %% [markdown]
#  ## 5.String (str)
#                     - a combination or sequence of characters (alphabets,number,special characters)
#                     - we can use single quotes or double quotes to represent strings.

# %%
s='Welcome'       #single quote
s
# Out:
# 'Welcome'

# %%
s="welcome"       #double quote
s
# Out:
# 'welcome'

# %%
s='''welcome'''        #triple quote
s
# Out:
# 'welcome'

# %%
s1='''abhay              
gajanan
pathe'''
s1           #for para use '''------'''
# Out:
# 'abhay              \ngajanan\npathe'

# %%
type(s1)
# Out:
# str

# %%
id(s1)
# Out:
# 2589848577456
